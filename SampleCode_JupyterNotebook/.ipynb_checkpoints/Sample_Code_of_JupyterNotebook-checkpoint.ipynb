# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#sg = np.random.SeedSequence(1234)
#x = np.random.MT19937(sg)
np.random.seed(324)
x = np.random.randn(1000)
plt.hist(x, bins=20)
plt.show()

# %% [markdown]
# $$
# J \left( \phi(z), y; \boldsymbol{w} \right) =
# -y \log{\left( \phi(z) \right)} - (1-y)\log{\left(1-\phi(z) \right)}
# $$
